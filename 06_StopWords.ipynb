# %% [markdown]
# # StopWords

# %%
paragraph = """Natural language processing field artificial intelligence focuses interaction computers humans natural language. many real-world applications,
 large amount text data contains common words known stopwords. words occur frequently contribute significantly overall meaning sentence. removing stopwords,
  reduce size data focus important words carry meaningful information. process especially useful tasks text classification, sentiment analysis, information retrieval,
   goal extract key insights textual data efficiently."""

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words("english")
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
stemmer = PorterStemmer()
sentences = nltk.sent_tokenize(paragraph)

# %%
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [stemmer.stem(word) for word in words if word not in set(stopwords.words("english"))]
    sentences[i] = " ".join(words)

# %%
sentences
# Out:
# ['natur languag process field artifici intellig focus interact comput human natur languag .',
#  'mani real-world applic , larg amount text data contain common word known stopword .',
#  'word occur frequent contribut significantli overal mean sentenc .',
#  'remov stopword , reduc size data focu import word carri meaning inform .',
#  'process especi use task text classif , sentiment analysi , inform retriev , goal extract key insight textual data effici .']

# %%
from nltk.stem import SnowballStemmer
snowballstemmer = SnowballStemmer("english")

# %%
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [snowballstemmer.stem(word) for word in words if word not in set(stopwords.words("english"))]
    sentences[i] = " ".join(words)

# %%
sentences
# Out:
# ['natur languag process field artifici intellig focus interact comput human natur languag .',
#  'mani real-world applic , larg amount text data contain common word known stopword .',
#  'word occur frequent contribut signific over mean sentenc .',
#  'remov stopword , reduc size data focu import word carri mean inform .',
#  'process especi use task text classif , sentiment analysi , inform retriev , goal extract key insight textual data effici .']

# %%
from nltk import WordNetLemmatizer
nltk.download("wordnet")
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in stop_words]
    sentences[i] = " ".join(words)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
sentences
# Out:
# ['natur languag process field artifici intellig focus interact comput human natur languag .',
#  'mani real-world applic , larg amount text data contain common word known stopword .',
#  'word occur frequent contribut signific mean sentenc .',
#  'remov stopword , reduc size data focu import word carri mean inform .',
#  'process especi use task text classif , sentiment analysi , inform retriev , goal extract key insight textual data effici .']

# %% [markdown]
# ## Parts of Speech Tags

# %%
paragraph = """I am delighted to be with you today. Whenever I see young minds, I feel energized and full of hope for our nation. You are not just students sitting in classrooms; you are the future leaders, innovators, scientists, teachers, and visionaries who will shape the destiny of our country. I have always believed that the strength of a nation lies in the ignited minds of its youth.

Today, I want to talk to you about a simple yet powerful idea — dreams.

Dream, dream, dream. Dreams transform into thoughts, and thoughts result in action. But I want you to understand something very clearly: dreams are not those which you see while sleeping. Dreams are those that do not let you sleep. When you have such a dream, it occupies your mind, it drives your actions, and it gives you a purpose in life.

Each one of you has a unique potential. You may come from different backgrounds, different cities, different families, but inside you lies a spark — a spark that can light up the world. The question is: will you recognize that spark, and will you nurture it?

When I was a young boy growing up in Rameswaram, I sold newspapers to support my family. Life was not easy, but I had dreams. I had teachers who inspired me, who told me that I could achieve something meaningful in life. That encouragement changed my path. It is not where you start, but how strong your desire is to reach your goal.

You must have a goal in life. Without a goal, life becomes directionless. Set a goal that is bigger than yourself — something that contributes not only to your success but also to the progress of society. When your goal aligns with a larger purpose, your efforts gain strength and meaning.

However, having a dream is not enough. You must be willing to work hard. There is no substitute for hard work. Success does not come easily; it comes through dedication, discipline, and perseverance. You will face failures. Do not be afraid of them. Failure is not the opposite of success; it is a part of success. In fact, failure teaches you lessons that success cannot.

I have experienced failures in my own career. There were moments when projects did not succeed, when efforts did not produce the desired results. But each failure taught me something new. It made me stronger, more determined, and more prepared for future challenges. So, my young friends, never fear failure. Instead, learn from it and move forward with greater confidence."""

# %%
import nltk
sentences = nltk.sent_tokenize(paragraph)

# %%
## We will find pos tag

nltk.download("averaged_perceptron_tagger_eng")

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word for word in words if word not in set(stopwords.words("english"))]
    print(nltk.pos_tag(words))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [('I', 'PRP'), ('delighted', 'VBD'), ('today', 'NN'), ('.', '.')]
# [('Whenever', 'WRB'), ('I', 'PRP'), ('see', 'VBP'), ('young', 'JJ'), ('minds', 'NNS'), (',', ','), ('I', 'PRP'), ('feel', 'VBP'), ('energized', 'JJ'), ('full', 'JJ'), ('hope', 'NN'), ('nation', 'NN'), ('.', '.')]
# [('You', 'PRP'), ('students', 'NNS'), ('sitting', 'VBG'), ('classrooms', 'NNS'), (';', ':'), ('future', 'JJ'), ('leaders', 'NNS'), (',', ','), ('innovators', 'NNS'), (',', ','), ('scientists', 'NNS'), (',', ','), ('teachers', 'NNS'), (',', ','), ('visionaries', 'NNS'), ('shape', 'VBP'), ('destiny', 'JJ'), ('country', 'NN'), ('.', '.')]
# ...
